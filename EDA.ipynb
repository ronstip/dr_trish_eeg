# %% [markdown]
# # EDA on Dr Trish data

# %%
import pandas as pd

all_users_data_path = "data/26 Feb all users/trish_all_users_data.csv"
path_to_identifiers_data = "data"

# %%
# read path_to_excel_identifiers_data
pd.read_excel(path_to_excel_identifiers_data)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # read path_to_excel_identifiers_data
# ----> 2 pd.read_excel(path_to_excel_identifiers_data)
#
# File ~/Documents/private_git_repos/dr_trish_eeg/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
df = pd.read_csv(all_users_data_path)
df.head()
# Out:
#    Alpha Recovery; Central (Cz); [Alpha(EO) after - Alpha(EO) before] / Alpha(EO) before  \
# 0                                                3.0
# 1                                                3.0
# 2                                                3.0
# 3                                                3.0
# 4                                                3.0
#
#    Alpha Recovery; Posterior (O1); [Alpha(EO) after - Alpha(EO) before] / Alpha(EO) before  \
# 0                                              -13.0
# 1                                              -13.0
# 2                                              -13.0
# 3                                              -13.0
# 4                                              -13.0
#
#    Alpha Response; Central (Cz); [Alpha(EC) - Alpha(EO)] / Alpha(EO)  \
# 0                                               32.0
# 1                                               32.0
# 2                                               32.0
# ...

# %%
df.iloc[0].to_dict()
# Out:
# {'Alpha Recovery; Central (Cz); [Alpha(EO) after - Alpha(EO) before] / Alpha(EO) before': 3.0,
#  'Alpha Recovery; Posterior (O1); [Alpha(EO) after - Alpha(EO) before] / Alpha(EO) before': -13.0,
#  'Alpha Response; Central (Cz); [Alpha(EC) - Alpha(EO)] / Alpha(EO)': 32.0,
#  'Alpha Response; Posterior (O1); [Alpha(EC) - Alpha(EO)] / Alpha(EO)': 15.0,
#  'Alpha Symmetry; Frontal Left and Right (F3, F4); Alpha (F3) / alpha (F4)': 1.12,
#  'Beta Balance; Frontal (Fz); HiBeta/Beta': 0.58,
#  'Beta Response While Counting; Central (Cz); [Beta(UT) - Beta(EC)] / Beta(EC)': -22.0,
#  'Beta Symmetry; Frontal Left and Right (F3, F4); Beta (F3) / beta (F4)': 0.79,
#  'Low-alpha/High-alpha Ratio; Frontal (Fz); Low-alpha (8-9Hz) / high-alpha (11-12Hz)': 1.24,
#  'Peak Alpha; Posterior (O1); The maximum amplitude value in the EEG frequency spectrum between 8 and 12 Hz': 10.0,
#  'QEEG_alpha_eyesClosed_Cz': 0.786,
#  'QEEG_alpha_eyesClosed_F3': 0.595,
#  'QEEG_alpha_eyesClosed_F4': 0.675,
# ...

# %%
df.groupby("patient_id").size().sort_values(ascending=False)
# Out:
# patient_id
# 356468d6-0d0b-4ce9-9b70-8f43bc051813    152
# d528e50b-f6e5-4495-aa23-eb37f9ec34d9     95
# 7fc32562-9814-4c06-bc46-bc9988d911c9     95
# 3aa1ee83-9bdd-447e-b7b6-e4886b13340e     80
# 2c969a3b-94a2-42aa-8828-0f00951261f4     58
#                                        ...
# 1860ccb9-cd73-4b29-a3c5-815aaa901359     17
# 8667f705-2b9d-4ebd-a91a-a58cd74251b1     16
# 097eb7ce-e370-4a24-bcc7-61726e2718e7     15
# fe9f9c1c-98fb-4bff-a360-077c518bb42f     14
# 4aec59c2-984d-4cf4-945a-61229c2909a6     14
# Length: 355, dtype: int64
